# %% [markdown]
# # CI280 - Final Project - Part B
# #
# # Data Preparation, Sort, Groupby and Plot( 100 pts)
#
# ## Name: Joanna Luchowska
# ## ID: 21507

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
plt.rc('figure', figsize=(10, 8))

# %%
df = pd.read_csv('covid-data.csv')

# %%
# limiting the display rows
pd.set_option('display.max_rows', 5)
df
# Out:
#       iso_code      continent       location        date  total_cases  \
# 0          ABW  North America          Aruba  2020-03-13          2.0
# 1          ABW  North America          Aruba  2020-03-19          NaN
# ...        ...            ...            ...         ...          ...
# 56319      NaN            NaN  International  2020-11-11        696.0
# 56320      NaN            NaN  International  2020-11-12        696.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0            2.0                 NaN           NaN         0.0
# 1            NaN               0.286           NaN         NaN
# ...          ...                 ...           ...         ...
# 56319        NaN                 NaN           7.0         NaN
# 56320        NaN                 NaN           7.0         NaN
#
#        new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 0                      NaN  ...       35973.781              NaN
# 1                      0.0  ...       35973.781              NaN
# ...                    ...  ...             ...              ...
# 56319                  NaN  ...             NaN              NaN
# 56320                  NaN  ...             NaN              NaN
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 0                        NaN                11.62             NaN
# 1                        NaN                11.62             NaN
# ...                      ...                  ...             ...
# 56319                    NaN                  NaN             NaN
# 56320                    NaN                  NaN             NaN
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0               NaN                     NaN                         NaN
# 1               NaN                     NaN                         NaN
# ...             ...                     ...                         ...
# 56319           NaN                     NaN                         NaN
# 56320           NaN                     NaN                         NaN
#
#        life_expectancy  human_development_index
# 0                76.29                      NaN
# 1                76.29                      NaN
# ...                ...                      ...
# 56319              NaN                      NaN
# 56320              NaN                      NaN
#
# [56003 rows x 49 columns]

# %%
df = df[ (df['location'] != 'World') ]
df
# Out:
#       iso_code      continent       location        date  total_cases  \
# 0          ABW  North America          Aruba  2020-03-13          2.0
# 1          ABW  North America          Aruba  2020-03-19          NaN
# ...        ...            ...            ...         ...          ...
# 56319      NaN            NaN  International  2020-11-11        696.0
# 56320      NaN            NaN  International  2020-11-12        696.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0            2.0                 NaN           NaN         0.0
# 1            NaN               0.286           NaN         NaN
# ...          ...                 ...           ...         ...
# 56319        NaN                 NaN           7.0         NaN
# 56320        NaN                 NaN           7.0         NaN
#
#        new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 0                      NaN  ...       35973.781              NaN
# 1                      0.0  ...       35973.781              NaN
# ...                    ...  ...             ...              ...
# 56319                  NaN  ...             NaN              NaN
# 56320                  NaN  ...             NaN              NaN
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 0                        NaN                11.62             NaN
# 1                        NaN                11.62             NaN
# ...                      ...                  ...             ...
# 56319                    NaN                  NaN             NaN
# 56320                    NaN                  NaN             NaN
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0               NaN                     NaN                         NaN
# 1               NaN                     NaN                         NaN
# ...             ...                     ...                         ...
# 56319           NaN                     NaN                         NaN
# 56320           NaN                     NaN                         NaN
#
#        life_expectancy  human_development_index
# 0                76.29                      NaN
# 1                76.29                      NaN
# ...                ...                      ...
# 56319              NaN                      NaN
# 56320              NaN                      NaN
#
# [56003 rows x 49 columns]

# %%
# Show number of records 
import random
number = random.randint(0,10000)
print("Joanna Luchowska, ID: 21507, ", number)
print('------------------------')

print("Number of records:" ,len(df))
# Out:
# Joanna Luchowska, ID: 21507,  5954
# ------------------------
# Number of records: 56321

# %% [markdown]
# ## C) Handing Missing Data and Ploting (20 pts)
#
# ### use isnull() vs. notnull()
# ### use dropna
# ### use replacena

# %%
# show last five rows
df.tail()
# Out:
#       iso_code continent       location        date  total_cases  new_cases  \
# 56316      NaN       NaN  International  2020-11-08        696.0        NaN
# 56317      NaN       NaN  International  2020-11-09        696.0        NaN
# 56318      NaN       NaN  International  2020-11-10        696.0        NaN
# 56319      NaN       NaN  International  2020-11-11        696.0        NaN
# 56320      NaN       NaN  International  2020-11-12        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 56316                 NaN           7.0         NaN                  NaN  ...
# 56317                 NaN           7.0         NaN                  NaN  ...
# 56318                 NaN           7.0         NaN                  NaN  ...
# 56319                 NaN           7.0         NaN                  NaN  ...
# 56320                 NaN           7.0         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 56316             NaN              NaN                    NaN
# 56317             NaN              NaN                    NaN
# 56318             NaN              NaN                    NaN
# 56319             NaN              NaN                    NaN
# 56320             NaN              NaN                    NaN
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 56316                  NaN             NaN           NaN
# 56317                  NaN             NaN           NaN
# 56318                  NaN             NaN           NaN
# 56319                  NaN             NaN           NaN
# 56320                  NaN             NaN           NaN
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 56316                     NaN                         NaN              NaN
# 56317                     NaN                         NaN              NaN
# 56318                     NaN                         NaN              NaN
# 56319                     NaN                         NaN              NaN
# 56320                     NaN                         NaN              NaN
#
#        human_development_index
# 56316                      NaN
# 56317                      NaN
# 56318                      NaN
# 56319                      NaN
# 56320                      NaN
#
# [5 rows x 49 columns]

# %%
# show the number of rows and columns of datafram 
df.shape
number = random.randint(0,10000)
print("Joanna Luchowska, ID: 21507, ", number)
print('------------------------')

# 1) Show the number records of miss data for continent ( 2 pts)
#    Show the the last five those records 

print('The number records missing data for continent')

print(len(df[df.continent.isnull()]))
df[df.continent.isnull()].tail()
# Out:
# Joanna Luchowska, ID: 21507,  7938
# ------------------------
# The number records missing data for continent
# 636
#       iso_code continent       location        date  total_cases  new_cases  \
# 56316      NaN       NaN  International  2020-11-08        696.0        NaN
# 56317      NaN       NaN  International  2020-11-09        696.0        NaN
# 56318      NaN       NaN  International  2020-11-10        696.0        NaN
# 56319      NaN       NaN  International  2020-11-11        696.0        NaN
# 56320      NaN       NaN  International  2020-11-12        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 56316                 NaN           7.0         NaN                  NaN  ...
# 56317                 NaN           7.0         NaN                  NaN  ...
# 56318                 NaN           7.0         NaN                  NaN  ...
# 56319                 NaN           7.0         NaN                  NaN  ...
# 56320                 NaN           7.0         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 56316             NaN              NaN                    NaN
# 56317             NaN              NaN                    NaN
# 56318             NaN              NaN                    NaN
# 56319             NaN              NaN                    NaN
# 56320             NaN              NaN                    NaN
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 56316                  NaN             NaN           NaN
# 56317                  NaN             NaN           NaN
# 56318                  NaN             NaN           NaN
# 56319                  NaN             NaN           NaN
# 56320                  NaN             NaN           NaN
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 56316                     NaN                         NaN              NaN
# 56317                     NaN                         NaN              NaN
# 56318                     NaN                         NaN              NaN
# 56319                     NaN                         NaN              NaN
# 56320                     NaN                         NaN              NaN
#
#        human_development_index
# 56316                      NaN
# 56317                      NaN
# 56318                      NaN
# 56319                      NaN
# 56320                      NaN
#
# [5 rows x 49 columns]

# %%
number = random.randint(0,10000)
print("Joanna Luchowska, ID: 21507, ", number)
print('------------------------')


# 2-3) Show the number records of miss data for continent and iso_code (2 pts)
#    Show the the last five those records ( 2 pts)

print('The number records missing data for continent and iso code: ')
print(len(df[df.continent.isnull() & df.iso_code.isnull()]))
df[df.continent.isnull() & df.iso_code.isnull()].tail()
# Out:
# Joanna Luchowska, ID: 21507,  7212
# ------------------------
# The number records missing data for continent and iso code:
# 318
#       iso_code continent       location        date  total_cases  new_cases  \
# 56316      NaN       NaN  International  2020-11-08        696.0        NaN
# 56317      NaN       NaN  International  2020-11-09        696.0        NaN
# 56318      NaN       NaN  International  2020-11-10        696.0        NaN
# 56319      NaN       NaN  International  2020-11-11        696.0        NaN
# 56320      NaN       NaN  International  2020-11-12        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 56316                 NaN           7.0         NaN                  NaN  ...
# 56317                 NaN           7.0         NaN                  NaN  ...
# 56318                 NaN           7.0         NaN                  NaN  ...
# 56319                 NaN           7.0         NaN                  NaN  ...
# 56320                 NaN           7.0         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 56316             NaN              NaN                    NaN
# 56317             NaN              NaN                    NaN
# 56318             NaN              NaN                    NaN
# 56319             NaN              NaN                    NaN
# 56320             NaN              NaN                    NaN
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 56316                  NaN             NaN           NaN
# 56317                  NaN             NaN           NaN
# 56318                  NaN             NaN           NaN
# 56319                  NaN             NaN           NaN
# 56320                  NaN             NaN           NaN
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 56316                     NaN                         NaN              NaN
# 56317                     NaN                         NaN              NaN
# 56318                     NaN                         NaN              NaN
# 56319                     NaN                         NaN              NaN
# 56320                     NaN                         NaN              NaN
#
#        human_development_index
# 56316                      NaN
# 56317                      NaN
# 56318                      NaN
# 56319                      NaN
# 56320                      NaN
#
# [5 rows x 49 columns]

# %%
number = random.randint(0,10000)
print("Joanna Luchowska, ID: 21507, ", number)
print('------------------------')



# 4-5) For the records for Poland, which columns has missing data (4 pts)
res = df[df['location']=='Poland']
res

col_names = res.columns
col_names


print('The following columns are missing data for Poland:')

print('Column name                        Missing Data')
print('------------------------------------------------')
for name in col_names:
    num = len(res[res[name].isnull()])
    if num > 0:
        print('{0: <40}'.format(name), num)
# Out:
# Joanna Luchowska, ID: 21507,  3413
# ------------------------
# The following columns are missing data for Poland:
# Column name                        Missing Data
# ------------------------------------------------
# new_cases_smoothed                       4
# total_deaths                             7
# new_deaths_smoothed                      4
# new_cases_smoothed_per_million           4
# total_deaths_per_million                 7
# new_deaths_smoothed_per_million          4
# icu_patients                             252
# icu_patients_per_million                 252
# hosp_patients                            45
# hosp_patients_per_million                45
# weekly_icu_admissions                    252
# weekly_icu_admissions_per_million        252
# weekly_hosp_admissions                   252
# weekly_hosp_admissions_per_million       252
# total_tests                              55
# new_tests                                57
# total_tests_per_thousand                 55
# new_tests_per_thousand                   57
# new_tests_smoothed                       61
# new_tests_smoothed_per_thousand          61
# tests_per_case                           61
# positive_rate                            61
# tests_units                              54
# stringency_index                         7
# extreme_poverty                          252
# handwashing_facilities                   252

# %%
number = random.randint(0,10000)
print("Joanna Luchowska, ID: 21507, ", number)
print('------------------------')

#df.columns

df.shape
# .dropna() vs. . dropna(how='all')

# 6) Show the result after droping rows which have at least one NaN data in the dataset ()  (2 pts)

cleaned = df.dropna()

print("Total records after using .dropn(): ")
print(len(cleaned))
# Out:
# Joanna Luchowska, ID: 21507,  7199
# ------------------------
# Total records after using .dropn():
# 0

# %%
number = random.randint(0,10000)
print("Joanna Luchowska, ID: 21507, ", number)
print('------------------------')

# 7) Show the result after after droping rows which all data is NaN in the dataset ()  (2 pts)

res = df[df['location']=='Poland']
res
cleaned = res.dropna(how='all')

print("Total records after using .dropna(how='all'):")
print(len(cleaned))
# Out:
# Joanna Luchowska, ID: 21507,  1498
# ------------------------
# Total records after using .dropna(how='all'):
# 252

# %%
number = random.randint(0,10000)
print("Joanna Luchowska, ID: 21507, ", number)
print('------------------------')

print(df.shape)
print('Original row number:', len(df))

# 8) Show the result after dropping the rows which continent or iso data is missing in the dataset
#    How many rows are dropped. (2 pts)

cleaned_data = df[df.continent.notnull() & df.iso_code.notnull()]
bad_data = df[df.continent.isnull() | df.iso_code.isnull()]
print('Results after droping all missing data of continent or iso_code in the dataset:')
print('New dataset included record number:', len(cleaned_data))
print('The number of rows droped:', len(bad_data))
# Out:
# Joanna Luchowska, ID: 21507,  2828
# ------------------------
# (56321, 49)
# Original row number: 56321
# Results after droping all missing data of continent or iso_code in the dataset:
# New dataset included record number: 55685
# The number of rows droped: 636

# %%
res = df[df['location']=='Brazil']
res[['location','handwashing_facilities']]
# Out:
#      location  handwashing_facilities
# 7202   Brazil                     NaN
# 7203   Brazil                     NaN
# ...       ...                     ...
# 7518   Brazil                     NaN
# 7519   Brazil                     NaN
#
# [318 rows x 2 columns]

# %%
# 9) Show Poland's handwashing_facilities information
#    Show the average of handwashing_facilities of worldwide level

import random
number = random.randint(0,10000)
print("Joanna Luchowska, ID: 21507, ", number)
print('------------------------')

#print(df['handwashing_facilities'].describe())


print("Handwashing_facilities values are missing in Poland")
res = df[df['location']=='Poland']
print(len(res))
print()

data = res[res['handwashing_facilities'].isnull()] [['location','date','handwashing_facilities']]
print(data)
print()

avg = df['handwashing_facilities'].mean()
print('The average of handwashing facilities worldwide:', format(avg, '.0f'))
# Out:
# Joanna Luchowska, ID: 21507,  5048
# ------------------------
# Handwashing_facilities values are missing in Poland
# 252
#
#       location        date  handwashing_facilities
# 41325   Poland  2020-03-04                     NaN
# 41326   Poland  2020-03-07                     NaN
# 41327   Poland  2020-03-08                     NaN
# 41328   Poland  2020-03-09                     NaN
# 41329   Poland  2020-03-10                     NaN
# ...        ...         ...                     ...
# 41572   Poland  2020-11-08                     NaN
# 41573   Poland  2020-11-09                     NaN
# 41574   Poland  2020-11-10                     NaN
# 41575   Poland  2020-11-11                     NaN
# 41576   Poland  2020-11-12                     NaN
#
# [252 rows x 3 columns]
#
# The average of handwashing facilities worldwide: 52

# %%
number = random.randint(0,10000)
print("Joanna Luchowska, ID: 21507, ", number)
print('------------------------')

import math

# 10) Replace handwashing_facilities in Poland as the average of worldwide level (2 pts)

res = df[df['location']=='Poland']
avg = df['handwashing_facilities'].mean()
avg = math.floor(avg)

print('Now handwashing facilities values are replaced by the average of worldwide level')
data

res['handwashing_facilities'].fillna(avg, inplace=True)
res[['location', 'date','handwashing_facilities']]
# Out:
# Joanna Luchowska, ID: 21507,  3141
# ------------------------
# Now handwashing facilities values are replaced by the average of worldwide level
# /Users/joanna/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
#       location        date  handwashing_facilities
# 41325   Poland  2020-03-04                    52.0
# 41326   Poland  2020-03-07                    52.0
# 41327   Poland  2020-03-08                    52.0
# 41328   Poland  2020-03-09                    52.0
# 41329   Poland  2020-03-10                    52.0
# ...        ...         ...                     ...
# 41572   Poland  2020-11-08                    52.0
# 41573   Poland  2020-11-09                    52.0
# 41574   Poland  2020-11-10                    52.0
# 41575   Poland  2020-11-11                    52.0
# 41576   Poland  2020-11-12                    52.0
#
# [252 rows x 3 columns]

# %% [markdown]
# # D) Sorting, Grouping and Plotting (30 points)
#
# ## df.sort_values(by=['a','b'], ascending = True)
# ## df.sort_index()
# ## df.groupby( )

# %%
number = random.randint(0,10000)
print("Joanna Luchowska, ID: 21507, ", number)
print('------------------------')

import matplotlib.pyplot as plt

# 1)  (3 pts) Find the top 10 countries which have the most covid cases

# Group all cases by location , become series
cases = df.groupby(df.location).new_cases.sum()
cases = cases.sort_values(ascending = False)
cases

res = cases.head(10)
countries = res.index

print('Ten countries which have the most covid cases:')
print('Country                Covid cases')
print('---------------------------------------------')
for country in countries:
    print('{0: <20}'.format(country), '\t', format(res[country],'.0f'))
# Out:
# Joanna Luchowska, ID: 21507,  4268
# ------------------------
# Ten countries which have the most covid cases:
# Country                Covid cases
# ---------------------------------------------
# World                	 52143259
# United States        	 10401132
# India                	 8683916
# Brazil               	 5675032
# France               	 1865538
# Russia               	 1836960
# Spain                	 1417709
# Argentina            	 1273342
# United Kingdom       	 1256725
# Colombia             	 1165326

# %%
number = random.randint(0,10000)
print("Joanna Luchowska, ID: 21507, ", number)
print('------------------------')


# 2) Use bar chart to show the top 10 countries which have the most covid cases. (3 pts)

res = cases.head(10)
res


res = cases.head(10)
print(res.index)
print(res.values)

res.plot(kind='bar', title='10 countries which have the most covid cases')
# Out:
# Joanna Luchowska, ID: 21507,  6001
# ------------------------
# Index(['World', 'United States', 'India', 'Brazil', 'France', 'Russia',
#        'Spain', 'Argentina', 'United Kingdom', 'Colombia'],
#       dtype='object', name='location')
# [52143259. 10401132.  8683916.  5675032.  1865538.  1836960.  1417709.
#   1273342.  1256725.  1165326.]

# %%
number = random.randint(0,10000)
print("Joanna Luchowska, ID: 21507, ", number)
print('------------------------')

# (3  pts)

# 3) Show worldwide, which ten day has the most new cases? 

#    Use line chart to show the top 10 days which have the most new covid cases 

cases = df.groupby(df.date).new_cases.sum()
cases = cases.sort_values(ascending = False)

res = cases.head(10)
res = res.sort_index()

days = res.index



print ('10 days which have the most Covid Cases')
print ('Date                     Covid Cases')
print ('---------------------------------------------------')

for day in days:
    print(day, '\t', format (res[day], '.0f'))



# Draw bar chart
plt.title('Top 10 days which have the most new Covid Cases')
plt.xlabel('Date')
plt.ylabel('Numbers')

plt.plot(res.index,res.values, color ='b')

res.plot (kind='line', rot = 45, linestyle = 'dashed' , marker = 'o')
# Out:
# Joanna Luchowska, ID: 21507,  436
# ------------------------
# 10 days which have the most Covid Cases
# Date                     Covid Cases
# ---------------------------------------------------
# 2020-10-30 	 1096238
# 2020-10-31 	 1084250
# 2020-11-05 	 1139462
# 2020-11-06 	 1180258
# 2020-11-07 	 1169024
# 2020-11-08 	 1146906
# 2020-11-09 	 1036378
# 2020-11-10 	 1107382
# 2020-11-11 	 1091932
# 2020-11-12 	 1117814

# %%
number = random.randint(0,10000)
print("Joanna Luchowska, ID: 21507, ", number)
print('------------------------')

# (3  pts)

# 4) On 2020-11-30, which ten countries has the most new cases? 

#    Use bar chart to show the top 10 location which have the most new covid cases 


res = df[df.date=='2020-11-08']


#Sorting cases
cases = res.sort_values(by='new_cases', ascending = False)


res = cases.head(10)[['location','new_cases']]
res = res.sort_index()


#Display dataframes
print("10 countries which have the most covid cases on 2020-11-08")
print("Country                 Covid cases")
print('----------------------------------------------------')


for i in res.index:
    country = res['location'][i]
    new_cases = res['new_cases'][i]
    print('{0: <20}'.format(country), '\t', format(new_cases, '.0f'))
    
    
      
# Draw bar chart
plt.title("10 countries which have the most covid cases on 2020-11-08")
plt.xlabel("Date")
plt.ylabel("Numbers")

plt.bar(res['location'],res['new_cases'], color='b')
# Out:
# Joanna Luchowska, ID: 21507,  7416
# ------------------------
# 10 countries which have the most covid cases on 2020-11-08
# Country                 Covid cases
# ----------------------------------------------------
# Germany              	 16017
# France               	 86852
# United Kingdom       	 24957
# India                	 45674
# Italy                	 39809
# Poland               	 27875
# Russia               	 20396
# Ukraine              	 10746
# United States        	 121413
# World                	 573453
# <BarContainer object of 10 artists>

# %%
number = random.randint(0,10000)
print("Joanna Luchowska, ID: 21507, ", number)
print('------------------------')

# (3  pts)


#  5)  Show last seven days, the new cases in Poland(Chose one country),
#      Plot a line chart

cases = df[df.location=='Poland'].sort_values(by='date', ascending=True)
cases
res = cases[['date','new_cases']].tail(7)

print('\nIn the past seven days the new cases in Poland')
print('Date               Covid cases')
print('------------------------------------------------')

dates = res['date']
for i in res.index:
    print(res['date'][i], '\t', format(res['new_cases'][i], '.0f'))

plt.title('New covid cases in past ten days in Poland')
plt.xlabel('Date')
plt.ylabel('Numbers')

plt.plot(res['date'],res['new_cases'],color='b')
# Out:
# Joanna Luchowska, ID: 21507,  8108
# ------------------------
#
# In the past seven days the new cases in Poland
# Date               Covid cases
# ------------------------------------------------
# 2020-11-06 	 27143
# 2020-11-07 	 27086
# 2020-11-08 	 27875
# 2020-11-09 	 24785
# 2020-11-10 	 21713
# 2020-11-11 	 25454
# 2020-11-12 	 25221

# %%
number = random.randint(0,10000)
print("Joanna Luchowska, ID: 21507, ", number)
print('------------------------')


# 6-7) Group by contient, show total of new covid cases for each contient and sorted by total number
#    Plot the result by pie chart (3 pts)


df
res = df.groupby(df.continent).new_cases.sum().sort_values(ascending=False)

print('Total COVID-19 new cases by continent')
print('-------------------------------------')
names = res.index
for name in names:
    print('{0: <20}'.format(name), '\t', format(res[name], '.0f'))

res.plot(kind='pie', title='Covid new caases of percentages by continent', autopct='%1.1f%%')
# Out:
# Joanna Luchowska, ID: 21507,  7147
# ------------------------
# Total COVID-19 new cases by continent
# -------------------------------------
# Asia                 	 14762053
# Europe               	 12908695
# North America        	 12439797
# South America        	 10064053
# Africa               	 1918097
# Oceania              	 46830

# %%
res
# Out:
#             location    population
# 10332          China  1.439324e+09
# 24490          India  1.380004e+09
# ...              ...           ...
# 56476        Vatican  8.090000e+02
# 59920  International           NaN
#
# [190 rows x 2 columns]

# %%
number = random.randint(0,10000)
print("Joanna Luchowska, ID: 21507, ", number)
print('------------------------')

# 8) Show the top 10 countries which have the most population  (3 pts)


res = df[df.date=='2020-11-08'][['location', 'population']].sort_values(by = 'population', ascending = False)
res = res.head(10)
res.index

print('Top 10 countries which have the most population:')
for i in res.index:
    print('{0: <20}'.format(res['location'][i]), format(res['population'][i], '.0f'))

res2 = res.set_index('location')
# Out:
# Joanna Luchowska, ID: 21507,  8172
# ------------------------
# Top 10 countries which have the most population:
# World                7794798729
# China                1439323774
# India                1380004385
# United States        331002647
# Indonesia            273523621
# Pakistan             220892331
# Brazil               212559409
# Nigeria              206139587
# Bangladesh           164689383
# Russia               145934460

# %%
number = random.randint(0,10000)
print("Joanna Luchowska, ID: 21507, ", number)
print('------------------------')

# 9-10) Show the world poplation
#      Show the  population by each continent and show it as pie chart (6 pts)


data = df[df.date=='2020-11-30']
pop_sum = data['population'].sum()
print('The world population', pop_sum)
print()

data = df[df.date=='2020-11-30'][['continent', 'location', 'date', 'population']]

res = df.groupby([df.continent]).population.sum().sort_values(ascending = False)

print('Population by continent')
print('--------------------------------------')
names = res.index
for name in names:
    print('{0: <20}'.format(name), '\t', format(res[name], '.0f'))

res.plot(kind='pie', title='Covid new cases of percentages by continent', autopct='%1.1f%%')
# Out:
# Joanna Luchowska, ID: 21507,  6467
# ------------------------
# The world population 0.0
#
# Population by continent
# --------------------------------------
# Asia                 	 1427892009265
# Africa               	 354166662782
# Europe               	 228735074965
# North America        	 182216265341
# South America        	 123534039010
# Oceania              	 12230293958
